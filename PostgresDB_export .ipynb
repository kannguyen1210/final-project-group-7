# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# Dependencies for interaction with database:
from sqlalchemy import create_engine
from sqlalchemy.orm import Session

# Machine Learning dependencies:
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from collections import Counter
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

import numpy as np

# %%
# Create engine and link to AWS server database:
engine = create_engine('postgresql://postgres:Common123@database-1.cukfyvhxl6ur.us-west-1.rds.amazonaws.com:5432/postgres')
connect = engine.connect()

# %%
# Create session:
session = Session(engine)

# %%
# Import clean_dataset_2016 table:
fatal_ec_w_demog_df = pd.read_sql("SELECT * FROM fatal_ec_w_demog", connect)

# %%
fatal_ec_w_demog_df.head()
# Out:
#    unique_id              full_name   age  gender                    race  \
# 0          1  LaTanya Janelle McCoy  24.0  Female  African-American/Black
# 1          2          Lester Miller  53.0    Male        Race unspecified
# 2          3        Derrick E. Tate  23.0    Male        Race unspecified
# 3          4    John Edward Pittman  45.0    Male  African-American/Black
# 4          5       John Frank Brown  20.0    Male  African-American/Black
#
#          race_w_imputation  imputation_probability date_of_injury  \
# 0   African-American/Black                     NaN     2000-01-02
# 1   African-American/Black                0.947676     2000-01-02
# 2  European-American/White                0.941666     2000-01-05
# 3   African-American/Black                     NaN     2000-01-05
# 4   African-American/Black                     NaN     2000-01-05
#
#          location_of_injury location_of_death_city  ...  \
# 0      5700 block Mack Road             Sacramento  ...
# 1     4850 Flakes Mill Road              Ellenwood  ...
# 2  1900 block W Reynolds St                Pontiac  ...
# 3                      None                 Dothan  ...
# 4       56 Jesse Hill Jr Dr                Atlanta  ...
#
#           intentional_use_of_force symptoms_of_mental_illness year_of_injury  \
# 0                          Pursuit                         No           2000
# 1  Intentional use of deadly force                         No           2000
# 2  Intentional use of deadly force                         No           2000
# 3  Intentional use of deadly force                    Unknown           2000
# 4                              Yes        Drug or alcohol use           2000
#
#    white  black hispanic  asian indian hawaii  other
# 0  0.364  0.053    0.395  0.147  0.004  0.004  0.033
# 1  0.520  0.313    0.098  0.041  0.002  0.001  0.025
# 2  0.609  0.136    0.176  0.056  0.001  0.000  0.022
# 3  0.654  0.265    0.044  0.014  0.004  0.000  0.019
# 4  0.520  0.313    0.098  0.041  0.002  0.001  0.025
#
# [5 rows x 28 columns]

# %%
shootings_wp_w_demog_df = pd.read_sql("SELECT * FROM shootings_wp_w_demog", connect)

# %%
shootings_wp_w_demog_df.head()
# Out:
#    unique_id           full_name date_of_death   manner_of_death       armed  \
# 0          3          Tim Elliot    2015-01-02              shot         gun
# 1          4    Lewis Lee Lembke    2015-01-02              shot         gun
# 2          5  John Paul Quintero    2015-01-03  shot and Tasered     unarmed
# 3          8     Matthew Hoffman    2015-01-04              shot  toy weapon
# 4          9   Michael Rodriguez    2015-01-04              shot    nail gun
#
#     age gender race           city state  ...  threat_level         flee  \
# 0  53.0      M    A        Shelton    WA  ...        attack  Not fleeing
# 1  47.0      M    W          Aloha    OR  ...        attack  Not fleeing
# 2  23.0      M    H        Wichita    KS  ...         other  Not fleeing
# 3  32.0      M    W  San Francisco    CA  ...        attack  Not fleeing
# 4  39.0      M    H          Evans    CO  ...        attack  Not fleeing
#
#   body_camera  white  black  hispanic  asian  indian  hawaii  other
# 0       False  0.675  0.038     0.130  0.089   0.011   0.006  0.050
# 1       False  0.750  0.018     0.134  0.047   0.009   0.003  0.040
# 2       False  0.757  0.055     0.122  0.028   0.006   0.000  0.032
# 3       False  0.364  0.053     0.395  0.147   0.004   0.004  0.033
# 4       False  0.678  0.038     0.218  0.032   0.005   0.001  0.028
#
# [5 rows x 21 columns]
